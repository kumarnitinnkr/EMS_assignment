# %% [markdown]
# # Neural Network from Scratch — Executed Notebook
#
# This notebook demonstrates a NumPy-only 2-layer neural network trained to recognize letters A, B, C (5x6 binary images).

# %% [markdown]
# ## Templates and Predictions

# %%
Templates predictions and images
# Out:
# Letter: A\nPredicted: A\nProbs: [0.9408 0.0433 0.0511]\n\nLetter: B\nPredicted: B\nProbs: [0.0398 0.9377 0.055 ]\n\nLetter: C\nPredicted: C\nProbs: [0.0524 0.0487 0.9395]\n\n

# %% [markdown]
# ## Training Logs

# %%
Training logs
# Out:
# Epoch 1/300 - Loss: 0.378039 - Acc: 0.3333\nEpoch 51/300 - Loss: 0.236191 - Acc: 1.0000\nEpoch 101/300 - Loss: 0.064034 - Acc: 1.0000\nEpoch 151/300 - Loss: 0.023289 - Acc: 1.0000\nEpoch 201/300 - Loss: 0.012928 - Acc: 1.0000\nEpoch 251/300 - Loss: 0.008683 - Acc: 1.0000\n

# %% [markdown]
# ## Loss & Accuracy Plot

# %%
Loss & Accuracy

# %% [markdown]
# ## Noisy Samples Predictions

# %%
Noisy samples
# Out:
# A noisy 1 -> Pred: A, probs: [0.916 0.076 0.04 ]\nA noisy 2 -> Pred: A, probs: [0.929 0.047 0.058]\nA noisy 3 -> Pred: A, probs: [0.92  0.064 0.047]\nB noisy 1 -> Pred: B, probs: [0.087 0.891 0.048]\nB noisy 2 -> Pred: B, probs: [0.034 0.881 0.13 ]\nB noisy 3 -> Pred: B, probs: [0.057 0.916 0.055]\nC noisy 1 -> Pred: C, probs: [0.049 0.08  0.91 ]\nC noisy 2 -> Pred: C, probs: [0.053 0.048 0.94 ]\nC noisy 3 -> Pred: C, probs: [0.088 0.053 0.89 ]\n

# %% [markdown]
# ## Notes
# - Architecture: 30 -> 12 -> 3 (sigmoid)
# - Loss: MSE
# - Training: batch gradient descent
#
# Saved files: executed notebook and image files.
